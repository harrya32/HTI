# %%
import torch

# %%
reacher_1 = torch.load("NLOT/data/reacher_data_1.pt")
reacher_5 = torch.load("NLOT/data/reacher_data_5.pt")

# %%
reacher_data = torch.stack([reacher_1, reacher_5], dim=0)

# %%
torch.save(reacher_data, "NLOT/data/reacher_data.pt")

# %%
reacher_data
# Out:
# tensor([[[-3.4387e-01, -3.4901e-01,  7.8155e-01,  ...,  2.3702e+00,
#            1.4051e+00,  0.0000e+00],
#          [-2.7520e-01, -3.2201e-01,  7.7890e-01,  ...,  2.3632e+00,
#            1.3187e+00,  0.0000e+00],
#          [-1.8653e-01, -2.7562e-01,  7.6956e-01,  ...,  2.3375e+00,
#            1.0778e+00,  0.0000e+00],
#          ...,
#          [ 3.3202e-03, -2.5595e-03, -2.6520e+00,  ..., -6.3647e-01,
#           -1.2342e-01,  0.0000e+00],
#          [ 3.2248e-03, -2.1520e-03, -2.6568e+00,  ..., -6.3896e-01,
#           -1.1939e-01,  0.0000e+00],
#          [ 3.0484e-03, -1.8556e-03, -2.6611e+00,  ..., -6.4122e-01,
#           -1.1590e-01,  0.0000e+00]],
#
#         [[-1.4352e-01, -1.5696e-01,  7.8155e-01,  ...,  2.3702e+00,
#            1.4051e+00,  0.0000e+00],
#          [-1.4590e-01, -1.3144e-01,  7.7890e-01,  ...,  2.3632e+00,
#            1.3187e+00,  0.0000e+00],
#          [-1.2852e-01, -1.0528e-01,  7.6956e-01,  ...,  2.3375e+00,
#            1.0778e+00,  0.0000e+00],
#          ...,
#          [ 1.4149e-02, -8.9226e-03, -2.6520e+00,  ..., -6.3647e-01,
#           -1.2342e-01,  0.0000e+00],
#          [ 1.3804e-02, -8.8870e-03, -2.6568e+00,  ..., -6.3896e-01,
#           -1.1939e-01,  0.0000e+00],
#          [ 1.3446e-02, -8.8875e-03, -2.6611e+00,  ..., -6.4122e-01,
#           -1.1590e-01,  0.0000e+00]]])
