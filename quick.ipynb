# %%
import torch

# %%
reacher_1 = torch.load("NLOT/data/reacher_data_1.pt")
reacher_5 = torch.load("NLOT/data/reacher_data_5.pt")

# %%
reacher_data = torch.stack([reacher_1, reacher_5], dim=0)

# %%
torch.save(reacher_data, "NLOT/data/reacher_data.pt")

# %%
reacher_data
# Out:
# tensor([[[ 1.3705e-01,  2.3504e-01,  8.0017e-01,  ..., -1.4179e-02,
#           -1.6679e+00,  0.0000e+00],
#          [ 1.1142e-01,  1.9282e-01,  8.0011e-01,  ..., -1.5647e-02,
#           -1.6307e+00,  0.0000e+00],
#          [ 8.5964e-02,  1.6089e-01,  7.9963e-01,  ..., -2.1239e-02,
#           -1.5270e+00,  0.0000e+00],
#          ...,
#          [ 1.5499e-03,  1.2324e-03,  1.8468e-01,  ..., -8.4985e-01,
#           -3.2220e-01,  0.0000e+00],
#          [ 1.9799e-03,  7.2191e-04,  1.9407e-01,  ..., -8.4381e-01,
#           -3.2837e-01,  0.0000e+00],
#          [ 2.3016e-03,  3.0129e-04,  2.0301e-01,  ..., -8.3782e-01,
#           -3.3407e-01,  0.0000e+00]],
#
#         [[ 7.2184e-02,  6.4515e-02,  8.0017e-01,  ..., -1.4179e-02,
#           -1.6679e+00,  0.0000e+00],
#          [ 5.3603e-02,  4.6943e-02,  8.0011e-01,  ..., -1.5647e-02,
#           -1.6307e+00,  0.0000e+00],
#          [ 3.2197e-02,  2.6278e-02,  7.9963e-01,  ..., -2.1239e-02,
#           -1.5270e+00,  0.0000e+00],
#          ...,
#          [ 2.5519e-02,  7.0846e-02,  1.8468e-01,  ..., -8.4985e-01,
#           -3.2220e-01,  0.0000e+00],
#          [ 2.4766e-02,  7.0401e-02,  1.9407e-01,  ..., -8.4381e-01,
#           -3.2837e-01,  0.0000e+00],
#          [ 2.4033e-02,  7.0001e-02,  2.0301e-01,  ..., -8.3782e-01,
#           -3.3407e-01,  0.0000e+00]]])
