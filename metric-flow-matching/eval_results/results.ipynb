# %%
import pandas as pd
import numpy as np

def print_results(results, name):
    mean = np.mean(results)
    std = np.std(results)
    ci = std / np.sqrt(len(results))
    print(f"{name}: {mean:.3f} ± {ci:.3f}")

results_dropout = pd.read_csv("batch_results.tsv", sep="\t")
results_dropout_cfm = pd.read_csv("batch_results_cfm.tsv", sep="\t")
results_quantile = pd.read_csv("quantile_results.tsv", sep="\t")

# %%
print_results(list(results_dropout['mean_emd_eval']), "MFM")
# Out:
# MFM: 0.480 ± 0.020

# %%
print_results(list(results_quantile['avg_mse']), "MFM")
# Out:
# MFM: 1.387 ± 0.022

# %%
print_results(list(results_dropout_cfm['mean_emd_eval']), "CFM")
# Out:
# CFM: 0.464 ± 0.021
