# %%
import torch

data = torch.load("./diffusion_2moons_dropout.pt")

# %%
data
# Out:
# tensor([[[ 0.4606,  0.5787,  0.0000],
#          [-1.7120,  0.3725,  0.0000],
#          [ 0.5640, -0.3484,  0.0000],
#          ...,
#          [-0.5657, -0.2726,  1.0000],
#          [-0.5330,  0.2315,  1.0000],
#          [ 0.6222, -1.5341,  1.0000]],
#
#         [[ 0.6068, -0.4838,  0.0000],
#          [ 0.6611,  0.1938,  0.0000],
#          [-0.1744,  1.3073,  0.0000],
#          ...,
#          [-0.4846, -0.7409,  1.0000],
#          [-0.5027,  0.0533,  1.0000],
#          [ 1.7600,  0.4343,  1.0000]],
#
#         [[ 0.5309, -0.1447,  0.0000],
#          [-1.6291,  0.6337,  0.0000],
#          [ 0.1635,  1.0807,  0.0000],
#          ...,
#          [-0.5914, -0.1032,  1.0000],
#          [-0.6603,  0.0806,  1.0000],
#          [-0.6071, -0.2186,  1.0000]],
#
#         ...,
#
#         [[-0.4143,  0.9194,  0.0000],
#          [-0.5106,  1.2207,  0.0000],
#          [ 0.0331,  1.4745,  0.0000],
#          ...,
#          [-0.1283, -0.8868,  1.0000],
# ...

# %%
data.shape
# Out:
# torch.Size([11, 1000, 3])
